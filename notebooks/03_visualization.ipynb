# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from artifacts.persistence import load_utility_artifact

UTILITY_ARTIFACT_ROOT = PROJECT_ROOT / "artifacts" / "utility"
UTILITY_ARTIFACT_PATH = max(
    UTILITY_ARTIFACT_ROOT.glob("utility_*"),
    key=lambda path: path.name,
)

utility_data, meatadata_utility = load_utility_artifact(UTILITY_ARTIFACT_PATH)

# %%
meatadata_utility

# %%
utility_data

# %%
from artifacts.persistence import load_leakage_artifact

UTILITY_ARTIFACT_ROOT = PROJECT_ROOT / "artifacts" / "mia"
UTILITY_ARTIFACT_PATH = max(
    UTILITY_ARTIFACT_ROOT.glob("mia_*"),
    key=lambda path: path.name,
)

leakage_data, meatadata_leakage = load_leakage_artifact(UTILITY_ARTIFACT_PATH)

# %%
leakage_data

# %%
meatadata_leakage
